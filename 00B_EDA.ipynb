# %%
#Import packages
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
###Import dataset

#Import train
train=pd.read_csv("heart-attack-risk-analysis/train.csv")

# %%
#describe dataset
train.describe()
# Out:
#                Age  Cholesterol   Heart Rate     Diabetes  Family History  \
# count  7010.000000  7010.000000  7010.000000  7010.000000     7010.000000
# mean     53.510414   259.880742    75.105991     0.652782        0.491869
# std      21.290957    80.709248    20.507160     0.476120        0.499970
# min      18.000000   120.000000    40.000000     0.000000        0.000000
# 25%      35.000000   192.000000    57.000000     0.000000        0.000000
# 50%      53.000000   259.000000    75.000000     1.000000        0.000000
# 75%      72.000000   329.000000    93.000000     1.000000        1.000000
# max      90.000000   400.000000   110.000000     1.000000        1.000000
#
#            Smoking      Obesity  Alcohol Consumption  Exercise Hours Per Week  \
# count  7010.000000  7010.000000          7010.000000              7010.000000
# mean      0.896291     0.499857             0.595863                 9.979109
# ...

# %%
#Check for missing data
sns.heatmap(train.isna())
# Out:
# <Axes: >

# %%
train.columns
# Out:
# Index(['Patient ID', 'Age', 'Sex', 'Cholesterol', 'Blood Pressure',
#        'Heart Rate', 'Diabetes', 'Family History', 'Smoking', 'Obesity',
#        'Alcohol Consumption', 'Exercise Hours Per Week', 'Diet',
#        'Previous Heart Problems', 'Medication Use', 'Stress Level',
#        'Sedentary Hours Per Day', 'Income', 'BMI', 'Triglycerides',
#        'Physical Activity Days Per Week', 'Sleep Hours Per Day', 'Country',
#        'Continent', 'Hemisphere', 'Heart Attack Risk'],
#       dtype='object')

# %%
train.head()
# Out:
#   Patient ID  Age     Sex  Cholesterol Blood Pressure  Heart Rate  Diabetes  \
# 0    RDG0550   33    Male          200         129/90          48         0
# 1    NMA3851   56  Female          262        159/105          46         1
# 2    TUI5807   19  Female          140        161/109          54         0
# 3    YYT5016   50  Female          163         120/62          53         0
# 4    ZAC5937   89  Female          144        153/110          92         1
#
#    Family History  Smoking  Obesity  ...  Sedentary Hours Per Day  Income  \
# 0               1        1        1  ...                 0.138443  184066
# 1               0        1        0  ...                 0.369552  211755
# 2               1        0        0  ...                 8.646334  252203
# 3               1        1        1  ...                 1.107884  121954
# 4               0        1        0  ...                 1.337570  180121
#
#          BMI  Triglycerides  Physical Activity Days Per Week  \
# ...

# %%
#Country Continent and Hemisphere
train[['Country','Continent','Hemisphere']]
# Out:
#              Country      Continent           Hemisphere
# 0          Argentina  South America  Southern Hemisphere
# 1            Nigeria         Africa  Northern Hemisphere
# 2           Thailand           Asia  Northern Hemisphere
# 3              Spain         Europe  Southern Hemisphere
# 4            Germany         Europe  Northern Hemisphere
# ...              ...            ...                  ...
# 7005          France         Europe  Northern Hemisphere
# 7006  United Kingdom         Europe  Northern Hemisphere
# 7007        Colombia  South America  Northern Hemisphere
# 7008           Spain         Europe  Southern Hemisphere
# 7009           India           Asia  Northern Hemisphere
#
# [7010 rows x 3 columns]

# %%
train.Country.unique()
# Out:
# array(['Argentina', 'Nigeria', 'Thailand', 'Spain', 'Germany', 'France',
#        'South Africa', 'Colombia', 'Italy', 'China', 'Vietnam',
#        'United States', 'Japan', 'Canada', 'India', 'United Kingdom',
#        'New Zealand', 'Brazil', 'South Korea', 'Australia'], dtype=object)

# %%
dict(train.dtypes)
# Out:
# {'Patient ID': dtype('O'),
#  'Age': dtype('int64'),
#  'Sex': dtype('O'),
#  'Cholesterol': dtype('int64'),
#  'Blood Pressure': dtype('O'),
#  'Heart Rate': dtype('int64'),
#  'Diabetes': dtype('int64'),
#  'Family History': dtype('int64'),
#  'Smoking': dtype('int64'),
#  'Obesity': dtype('int64'),
#  'Alcohol Consumption': dtype('int64'),
#  'Exercise Hours Per Week': dtype('float64'),
#  'Diet': dtype('O'),
#  'Previous Heart Problems': dtype('int64'),
#  'Medication Use': dtype('int64'),
#  'Stress Level': dtype('int64'),
#  'Sedentary Hours Per Day': dtype('float64'),
#  'Income': dtype('int64'),
#  'BMI': dtype('float64'),
#  'Triglycerides': dtype('int64'),
#  'Physical Activity Days Per Week': dtype('int64'),
#  'Sleep Hours Per Day': dtype('int64'),
#  'Country': dtype('O'),
#  'Continent': dtype('O'),
#  'Hemisphere': dtype('O'),
#  'Heart Attack Risk': dtype('int64')}

# %%
#To explore object datatype
train[['Blood Pressure','Diet']]

#Blood pressure and Diet needs to be processed.
# Out:
#      Blood Pressure       Diet
# 0            129/90  Unhealthy
# 1           159/105    Average
# 2           161/109    Average
# 3            120/62    Healthy
# 4           153/110    Healthy
# ...             ...        ...
# 7005        104/105  Unhealthy
# 7006         134/99    Healthy
# 7007         134/84    Average
# 7008         144/76  Unhealthy
# 7009         172/60    Average
#
# [7010 rows x 2 columns]

# %%
Pie=train[['Patient ID','Heart Attack Risk']].groupby(by='Heart Attack Risk').count().reset_index(drop=False)
plt.pie(Pie['Patient ID'],labels=[0,1], autopct='%1.1f%%')
plt.title('Percentage of Individuals with Heart Attack Risks')
plt.show()
